# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')


BASE        = Path("~/HHM-Profiles-for-CA-Enzymes").expanduser()
REBASE      = BASE / "OUTPUT"
RESULTS = REBASE / "results"
HMM_LIB = REBASE / "hmmer_lib"  

# CA family names 
CA_FAMILIES = ["alpha", "beta", "gamma", "delta", "epsilon", "zeta", "eta", "theta", "iota"]

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 10

print(f"Base path: {BASE}")
print(f"Results path: {RESULTS}")
print(f"HMM library: {HMM_LIB}")
# Out:
# Base path: /Users/samkaplan/HHM-Profiles-for-CA-Enzymes
# Results path: /Users/samkaplan/HHM-Profiles-for-CA-Enzymes/OUTPUT/results
# HMM library: /Users/samkaplan/HHM-Profiles-for-CA-Enzymes/OUTPUT/hmmer_lib

# %%
def parse_all_hmms_from_file(hmm_file):
    AMINO_ACIDS = list("ACDEFGHIKLMNPQRSTVWY")
    all_hmms = {}
    
    with open(hmm_file, 'r') as f:
        current_emissions = []
        current_metadata = {}
        in_hmm = False
        aa_order = None
        
        for line in f:
            line_stripped = line.strip()
            
            #new HMM
            if line_stripped.startswith("HMMER3"):
                current_emissions = []
                current_metadata = {}
                in_hmm = False
                aa_order = None
                continue
            
            # parse metadata
            if line_stripped.startswith("NAME"):
                parts = line_stripped.split()
                current_metadata['name'] = parts[1] if len(parts) > 1 else ""
            elif line_stripped.startswith("LENG"):
                current_metadata['length'] = int(line_stripped.split()[1])
            elif line_stripped.startswith("ALPH"):
                current_metadata['alphabet'] = line_stripped.split()[1]
            
            # amino acid order from HMM header line
            elif line_stripped.startswith("HMM ") and "A" in line_stripped:
                parts = line_stripped.split()
                if len(parts) > 1:
                    aa_order = parts[1:]  # Skip 'HMM'
                in_hmm = True
                continue
            
            # skip the transition probability header line
            elif in_hmm and line_stripped.startswith("m->m"):
                continue
            
            # parse match state emissions
            if in_hmm and line_stripped and not line_stripped.startswith("//"):
                parts = line_stripped.split()
                
                # match state lines: position number followed by 20 emission values
                if len(parts) >= 21 and parts[0].isdigit():
                    log_probs = []
                    for p in parts[1:21]:
                        if p == '*':
                            log_probs.append(-np.inf)
                        else:
                            log_probs.append(-float(p))
                    
                    probs = np.exp(log_probs)
                    probs = probs / probs.sum()
                    current_emissions.append(probs)
            
            # end of current HMM - save it
            if line_stripped.startswith("//"):
                if current_emissions and current_metadata.get('name'):
                    if aa_order is None or len(aa_order) != 20:
                        aa_order = AMINO_ACIDS
                    
                    df = pd.DataFrame(current_emissions, columns=aa_order)
                    df.index = range(1, len(df) + 1)
                    df.index.name = 'position'
                    
                    name = current_metadata['name']
                    all_hmms[name] = (df, current_metadata)
                    print(f"  Parsed: {name} ({len(df)} positions)")
                
                # reset for next HMM
                current_emissions = []
                current_metadata = {}
                in_hmm = False
                aa_order = None
    
    return all_hmms

# parse the concat HMM file
ALL_HMM =  HMM_LIB/"all_classes.hmm"

if ALL_HMM.exists():
    print(f"Parsing HMMs from: {ALL_HMM}")
    all_hmms = parse_all_hmms_from_file(ALL_HMM)
    print(f"\nFound {len(all_hmms)} HMMs: {list(all_hmms.keys())}")
else:
    print(f"File not found: {ALL_HMM}")
    all_hmms = {}
# Out:
# Parsing HMMs from: /Users/samkaplan/HHM-Profiles-for-CA-Enzymes/OUTPUT/hmmer_lib/all_classes.hmm
#   Parsed: 8ca.alpha.45 (177 positions)
#   Parsed: 8ca.beta.45 (261 positions)
#   Parsed: 8ca.delta.45 (460 positions)
#   Parsed: 8ca.eta.45 (829 positions)
#   Parsed: 8ca.gamma.45 (181 positions)
#   Parsed: 8ca.iota.45 (216 positions)
#   Parsed: 8ca.theta.45 (580 positions)
#   Parsed: 8ca.zeta.45 (216 positions)
#
# Found 8 HMMs: ['8ca.alpha.45', '8ca.beta.45', '8ca.delta.45', '8ca.eta.45', '8ca.gamma.45', '8ca.iota.45', '8ca.theta.45', '8ca.zeta.45']

# %%
def plot_hmm_heatmap(emissions_df, title, figsize=(14, 6)):
    """Simple, clean heatmap for HMM emission probabilities."""
    fig, ax = plt.subplots(figsize=figsize)
    
    # n positions 
    data = emissions_df.iloc[:1000].T
    
    im = sns.heatmap(data, cmap='YlOrRd', ax=ax,
                     xticklabels=10, yticklabels=True,
                     cbar_kws={'label': 'Probability'})
    cbar = im.collections[0].colorbar
    cbar.set_label('Probability', fontsize=15)
    ax.tick_params(axis='both', labelsize=15) 

    
    ax.set_xlabel('Position', fontsize=15)
    ax.set_ylabel('Amino Acid', fontsize=15)
    ax.set_title(title, fontsize= 15)
    plt.tight_layout()
    return fig

# gen one heatmap per family
for hmm_name, (emissions_df, meta) in all_hmms.items():
    fig = plot_hmm_heatmap(emissions_df, f"{hmm_name} - Emission Probabilities")
    out_png = RESULTS / f"{hmm_name} - Emission Probabilities.png"
    fig.savefig(out_png, dpi=300)
    plt.show()
    plt.close()

# %%
# Get beta HMM and plot
beta_emissions, beta_meta = all_hmms['8ca.beta.45']
fig = plot_hmm_heatmap(beta_emissions, "Beta CA - Emission Probabilities")
out_png = RESULTS / f"Beta CA - Emission Probabilities.png"
fig.savefig(out_png, dpi=300)
plt.show()
plt.close()

# %%
LABELS_CSV = RESULTS / "uniprot_first_150000_labels_with_confidence.csv"

if not LABELS_CSV.exists():
    candidates = list(RESULTS.glob("*labels*.csv")) + list(RESULTS.glob("*predictions*.csv"))
    if candidates:
        LABELS_CSV = candidates[0]
        print(f"Using: {LABELS_CSV}")

if LABELS_CSV.exists():
    df = pd.read_csv(LABELS_CSV)
    print(f"Loaded {len(df):,} sequences")
    print(f"Columns: {list(df.columns)}")
    print(f"\nClass distribution:")
    print(df['pred_class'].value_counts())
    
    display(df.head(30))
else:
    print(f"Results file not found: {LABELS_CSV}")
    print("Please set LABELS_CSV to your classification results file.")
    df = None
# Out:
# Loaded 148,727 sequences
# Columns: ['seq_id', 'pred_model', 'bit_score', 'evalue', 'pred_class', 'confidence']
#
# Class distribution:
# pred_class
# alpha     56586
# gamma     43668
# beta      39997
# NO_HIT     7753
# delta       591
# eta         112
# theta        13
# zeta          5
# iota          2
# Name: count, dtype: int64
#                             seq_id    pred_model  bit_score        evalue  \
# 0   tr|A0A6A4STS7|A0A6A4STS7_SCOMX   8ca.beta.45       98.2  2.400000e-31
# 1   tr|A0A834BR83|A0A834BR83_ORYME   8ca.beta.45       97.4  4.100000e-31
# 2   tr|A0A8C8XNP7|A0A8C8XNP7_PANLE           NaN        NaN           NaN
# 3   tr|A0A9N8V4Z2|A0A9N8V4Z2_9GLOM  8ca.alpha.45       21.7  5.300000e-08
# 4   tr|A0AAD6AS60|A0AAD6AS60_9TELE   8ca.beta.45       99.5  9.500000e-32
# 5   tr|A0AAD9EVU2|A0AAD9EVU2_DISEL   8ca.beta.45       99.6  8.700000e-32
# 6            sp|A7MAQ2|DIOA3_DIOJA   8ca.beta.45      191.2  1.000000e-59
# ...

# %%
# Box/violin plot of E-value distributions for each predicted class.
# df: DataFrame with E-values and class predictions
# evalue_col: Column name for E-values
# class_col: Column name for predicted class
# threshold: E-value threshold to highlight

def plot_evalue_distributions(df, evalue_col='evalue', class_col='pred_class', threshold=1e-5, figsize=(12, 6)):
    # Filter out NO_HIT and missing values
    plot_df = df[df[class_col] != 'NO_HIT'].copy()
    plot_df = plot_df[plot_df[evalue_col].notna()]
    
    if len(plot_df) == 0:
        print("No data to plot after filtering.")
        return None, None
    
    # log-transform e-vals
    plot_df['log_evalue'] = np.log10(plot_df[evalue_col].clip(lower=1e-300))
    
    # Order classes by median E-val
    class_order = (plot_df.groupby(class_col)['log_evalue']
                   .median()
                   .sort_values()
                   .index.tolist())
    
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # violin plot
    ax1 = axes[0]
    sns.violinplot(data=plot_df, x=class_col, y='log_evalue', 
                   order=class_order, ax=ax1, inner='box', cut=0)
    ax1.axhline(y=np.log10(threshold), color='red', linestyle='--', 
                label=f'Threshold ({threshold:.0e})', linewidth=2)
    ax1.set_xlabel('Predicted CA Family')
    ax1.set_ylabel('log₁₀(E-value)')
    ax1.set_title('E-value Distribution by Family (Violin)')
    ax1.tick_params(axis='x', rotation=45)
    ax1.legend()
    
    # box plot
    ax2 = axes[1]
    sns.boxplot(data=plot_df, x=class_col, y='log_evalue',
                order=class_order, ax=ax2)
    ax2.axhline(
    y=5,
    color='red',
    linestyle='--',
    linewidth=2,
    label='E = 1e-5'
)
    ax2.set_xlabel('Predicted CA Family')
    ax2.set_ylabel('log10(E-value)')
    ax2.set_title('E-value Distribution by Family (Box)')
    ax2.tick_params(axis='x', rotation=45)
    ax2.legend()
    
    plt.tight_layout()
    return fig, axes

if df is not None:
    fig, axes = plot_evalue_distributions(df, threshold=1e-5)
    plt.show()

# %%
# Confidence score distribution
def plot_confidence_distribution(df, conf_col='confidence', class_col='pred_class',
                                 figsize=(14, 6)):
    """
    Plot distribution of confidence scores (-log10(E-value)) per class.
    """
    plot_df = df[df[class_col] != 'NO_HIT'].copy()
    plot_df = plot_df[plot_df[conf_col].notna()]
    
    if len(plot_df) == 0:
        print("No data to plot.")
        return None, None
    
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # Histogram of confidence scores
    ax1 = axes[0]
    ax1.hist(plot_df[conf_col], bins=50, edgecolor='black', alpha=0.7)
    ax1.axvline(x=5, color='red', linestyle='--', linewidth=2, label='Confidence=5 (E=1e-5)')
    ax1.set_xlabel('Confidence Score (-log10(E-value))', fontsize=16)
    ax1.set_ylabel('Count', fontsize=16)
    ax1.set_title('Overall Confidence Distribution', fontsize=18)
    ax1.tick_params(axis='both', labelsize=14)
    ax1.legend(fontsize=12)
    
    # Per-class boxplot
    ax2 = axes[1]
    class_order = (plot_df.groupby(class_col)[conf_col]
                   .median()
                   .sort_values(ascending=False)
                   .index.tolist())
    sns.boxplot(data=plot_df, x=class_col, y=conf_col,
                order=class_order, ax=ax2)
    ax2.axhline(y=5, color='red', linestyle='--', linewidth=2, label='E = 1e-5')
    ax2.set_xlabel('Predicted CA Family', fontsize=16)
    ax2.set_ylabel('Confidence Score', fontsize=16)
    ax2.set_title('Confidence by Family', fontsize=18)
    ax2.tick_params(axis='x', rotation=45, labelsize=14)
    ax2.tick_params(axis='y', labelsize=14)
    ax2.legend(fontsize=12)
    
    plt.tight_layout()
    return fig, axes

if df is not None and 'confidence' in df.columns:
    fig, axes = plot_confidence_distribution(df)
    
    # Save at 300 dpi
    out_png = RESULTS / "confidence_distribution.png"
    fig.savefig(out_png, dpi=300, bbox_inches='tight')
    
    plt.show()
    plt.close()

# %%
#e-value sum stats

def compute_evalue_stats(df, evalue_col='evalue', class_col='pred_class'):
    """
    Compute summary statistics for E-values by class.
    """
    plot_df = df[df[class_col] != 'NO_HIT'].copy()
    plot_df = plot_df[plot_df[evalue_col].notna()]
    
    stats = plot_df.groupby(class_col)[evalue_col].agg([
        ('count', 'count'),
        ('median', 'median'),
        ('mean', 'mean'),
        ('min', 'min'),
        ('max', 'max'),
        ('std', 'std')
    ])
    
    # % below threshold
    for thresh in [1e-5, 1e-10, 1e-20]:
        pct = plot_df.groupby(class_col)[evalue_col].apply(
            lambda x: (x < thresh).mean() * 100
        )
        stats[f'% < {thresh:.0e}'] = pct
    
    return stats.round(4)

if df is not None:
    stats = compute_evalue_stats(df)
    print("E-value Statistics by Predicted Class:")
    display(stats)
# Out:
# E-value Statistics by Predicted Class:
#             count  median    mean  min     max     std  % < 1e-05  % < 1e-10  \
# pred_class
# alpha       56586     0.0  0.0000  0.0  0.0003  0.0000    94.8874    37.6772
# beta        39997     0.0  0.0000  0.0  0.0001  0.0000    99.7225    97.2298
# delta         591     0.0  0.0000  0.0  0.0011  0.0001    94.9239    42.3012
# eta           112     0.0  0.2161  0.0  8.0000  1.2973    94.6429    89.2857
# gamma       43668     0.0  0.0000  0.0  0.0310  0.0001    99.9313    99.4046
# iota            2     0.0  0.0000  0.0  0.0000  0.0000   100.0000   100.0000
# theta          13     0.0  0.0000  0.0  0.0000  0.0000   100.0000   100.0000
# zeta            5     0.0  0.0000  0.0  0.0000  0.0000   100.0000    80.0000
#
#             % < 1e-20
# pred_class
# alpha         17.3859
# beta          88.7917
# delta         14.0440
# eta           87.5000
# gamma         95.7177
# iota          50.0000
# theta        100.0000
# zeta          60.0000

# %%
def compute_confidence_stats(df,
                             conf_col='confidence',
                             class_col='pred_class'):

    plot_df = df[df[class_col] != 'NO_HIT'].copy()
    plot_df = plot_df[plot_df[conf_col].notna()]

    stats = plot_df.groupby(class_col)[conf_col].agg([
        ('count', 'count'),
        ('median', 'median'),
        ('mean', 'mean'),
        ('min', 'min'),
        ('max', 'max'),
        ('std', 'std')
    ])

    # Confidence thresholds corresponding to E-values
    thresholds = {
        1e-5: 5,
        1e-10: 10,
        1e-20: 20
    }

    for e_thresh, conf_thresh in thresholds.items():
        pct = plot_df.groupby(class_col)[conf_col].apply(
            lambda x: (x >= conf_thresh).mean() * 100
        )
        stats[f'% ≥ {conf_thresh}'] = pct

    return stats.round(4)
if df is not None:
    conf_stats = compute_confidence_stats(df)
    print("Confidence Statistics by Predicted Class:")
    display(conf_stats)
# Out:
# Confidence Statistics by Predicted Class:
#             count    median      mean      min       max       std     % ≥ 5  \
# pred_class
# alpha       56586    8.9586   13.4715   3.5376  100.1024   12.3144   95.0412
# beta        39997   37.4559   41.5284   3.9586  318.7959   21.2002   99.7325
# delta         591    9.1549   26.7936   2.9586  188.0655   47.5900   94.9239
# eta           112  114.1221  166.8594  -0.9031  300.9208  112.2612   94.6429
# gamma       43668   56.6198   53.3972   1.5086  112.9208   14.3220   99.9359
# iota            2   64.3245   64.3245  18.3565  110.2924   65.0085  100.0000
# theta          13  132.5086  123.1338  22.4815  284.9208   85.1181  100.0000
# zeta            5  101.6021  110.6557   6.3665  320.5089  126.9198  100.0000
#
#               % ≥ 10    % ≥ 20
# pred_class
# alpha        37.8928   17.3930
# beta         97.2423   88.8442
# delta        42.4704   14.0440
# eta          89.2857   87.5000
# gamma        99.4046   95.7406
# ...

# %%
# import pandas as pd
# import numpy as np

# def stats_df_to_safe_latex(df,
#                            caption="Confidence statistics by predicted class.",
#                            label="tab:confidence_stats",
#                            float_fmt="{:.4f}",
#                            int_cols=None,
#                            index_name="Predicted class"):

#     # Defensive copy
#     df = df.copy()

#     # Ensure a name for the index
#     df.index.name = index_name

#     # Determine integer columns automatically if not provided:
#     if int_cols is None:
#         # treat 'count' as int if present, otherwise none
#         int_cols = []
#         if 'count' in df.columns:
#             int_cols.append('count')

#     # Prepare header labels: escape percent and replace >= symbol with latex math
#     def safe_col_label(s):
#         s = str(s)
#         s = s.replace('%', r'\%')         # percent sign
#         s = s.replace('≥', r'\(\geq\)')   # greater-or-equal
#         s = s.replace('<', r'\(<\)')      # less-than (if any)
#         s = s.replace('_', r'\_')         # underscore (in headers rare)
#         return s

#     col_labels = [safe_col_label(c) for c in df.columns]

#     # Column format: first column left, rest right aligned
#     ncols = df.shape[1] + 1  # +1 for the index column
#     col_spec = "l" + "r" * (ncols - 1)

#     # Header row
#     header_cells = [safe_col_label(df.index.name)] + col_labels
#     header_line = " & ".join(header_cells) + r" \\"

#     # Build body rows
#     rows = []
#     for idx, row in df.iterrows():
#         # escape underscores in the index label
#         idx_label = str(idx).replace('_', r'\_')

#         cells = [idx_label]
#         for col in df.columns:
#             val = row[col]
#             if pd.isna(val):
#                 cell = ""
#             else:
#                 # format integers for certain columns
#                 if col in int_cols:
#                     try:
#                         # convert to int if near-integer
#                         intval = int(round(float(val)))
#                         cell = f"{intval}"
#                     except Exception:
#                         cell = f"{float(val):.4f}"
#                 else:
#                     # format floats with float_fmt, but if value is effectively integer render as integer
#                     if np.isfinite(val):
#                         fv = float(val)
#                         if abs(fv - round(fv)) < 1e-9:
#                             cell = f"{int(round(fv))}"
#                         else:
#                             cell = float_fmt.format(fv)
#                     else:
#                         cell = ""
#             cells.append(cell)
#         rows.append(" & ".join(cells) + r" \\")

#     # Build LaTeX string
#     latex = []
#     latex.append(r"\begin{table}[htbp]")
#     latex.append(r"  \centering")
#     latex.append(f"  \\caption{{{caption}}}")
#     latex.append(f"  \\label{{{label}}}")
#     latex.append(f"  \\begin{{tabular}}{{{col_spec}}}")
#     latex.append(r"  \toprule")
#     latex.append("  " + header_line)
#     latex.append(r"  \midrule")
#     for r in rows:
#         latex.append("  " + r)
#     latex.append(r"  \bottomrule")
#     latex.append(r"  \end{tabular}")
#     latex.append(r"\end{table}")

#     return "\n".join(latex)


# # Example usage:
# latex_code = stats_df_to_safe_latex(conf_stats, caption="Confidence statistics by predicted class.", label="tab:confidence_stats")
# print(latex_code)

# %%
# e-value threshold senstiv analysis
#num hits at each threshold
# precision/recall trade-off
def plot_threshold_analysis(df, evalue_col='evalue', class_col='pred_class', true_col=None, figsize=(12, 5)):
    thresholds = np.logspace(-100, 0, 100)
    
    hits_df = df[df[class_col] != 'NO_HIT'].copy()
    hits_df = hits_df[hits_df[evalue_col].notna()]
    
    n_hits = []
    pct_retained = []
    
    for thresh in thresholds:
        passing = (hits_df[evalue_col] <= thresh).sum()
        n_hits.append(passing)
        pct_retained.append(100 * passing / len(hits_df) if len(hits_df) > 0 else 0)
    
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # num hits vs threshold
    ax1 = axes[0]
    ax1.semilogx(thresholds, n_hits, 'b-', linewidth=2)
    ax1.axvline(x=1e-5, color='red', linestyle='--', label='1e-5')
    ax1.axvline(x=1e-10, color='orange', linestyle='--', label='1e-10')
    ax1.set_xlabel('E-value Threshold')
    ax1.set_ylabel('Number of Hits Retained')
    ax1.set_title('Hits Retained vs E-value Threshold')
    ax1.legend()
    ax1.invert_xaxis()  #lower e-values on right
    
    # % retained vs threshold
    ax2 = axes[1]
    ax2.semilogx(thresholds, pct_retained, 'g-', linewidth=2)
    ax2.axvline(x=1e-5, color='red', linestyle='--', label='1e-5')
    ax2.axvline(x=1e-10, color='orange', linestyle='--', label='1e-10')
    ax2.set_xlabel('E-value Threshold')
    ax2.set_ylabel('% Hits Retained')
    ax2.set_title('Percentage Retained vs E-value Threshold')
    ax2.legend()
    ax2.invert_xaxis()
    ax2.set_ylim([0, 105])
    
    plt.tight_layout()
    
    # print thresholds
    print("\nHits retained at key thresholds:")
    for t in [1e-3, 1e-5, 1e-10, 1e-20, 1e-50]:
        n = (hits_df[evalue_col] <= t).sum()
        pct = 100 * n / len(hits_df) if len(hits_df) > 0 else 0
        print(f"  E <= {t:.0e}: {n:,} hits ({pct:.1f}%)")
    
    return fig, axes

if df is not None:
    fig, axes = plot_threshold_analysis(df)
    plt.show()
# Out:
# Hits retained at key thresholds:
#   E <= 1e-03: 140,966 hits (100.0%)
#   E <= 1e-05: 137,997 hits (97.9%)
#   E <= 1e-10: 104,114 hits (73.9%)
#   E <= 1e-20: 87,383 hits (62.0%)
#   E <= 1e-50: 42,698 hits (30.3%)

# %%
# E-value cumulative distribution plot
# Cumulative distribution function of E-values for each family
# What fraction of hits are below each E-value threshold
def plot_evalue_cdf(df, evalue_col='evalue', class_col='pred_class', figsize=(12, 7)):
    plot_df = df[df[class_col] != 'NO_HIT'].copy()
    plot_df = plot_df[plot_df[evalue_col].notna()]
    
    families = sorted(plot_df[class_col].unique())
    
    fig, ax = plt.subplots(figsize=figsize)
    
    for family in families:
        subset = plot_df[plot_df[class_col] == family][evalue_col].sort_values()
        cdf = np.arange(1, len(subset) + 1) / len(subset)
        ax.semilogx(subset, cdf, label=f'{family} (n={len(subset)})', linewidth=2)
    
    ax.axvline(x=1e-5, color='red', linestyle='--', linewidth=2, alpha=0.7, label='E=1e-5')
    ax.set_xlabel('E-value', fontsize=16)
    ax.set_ylabel('Cumulative Fraction', fontsize=16)
    ax.set_title('Cumulative E-value Distribution by Family', fontsize=18)
    ax.tick_params(axis='both', labelsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=16)
    ax.set_ylim([0, 1.02])
    ax.invert_xaxis()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig, ax

if df is not None:
    fig, ax = plot_evalue_cdf(df)
    
    # Save at 300 dpi
    out_png = RESULTS / "evalue_cdf_by_family.png"
    fig.savefig(out_png, dpi=300, bbox_inches='tight')
    
    plt.show()
    plt.close()

# %%
def calculate_information_content(emissions_df):
    """Calculate information content at each HMM position (bits)."""
    background = 1/20  # uniform background frequency
    ic_per_position = []
    
    for idx, row in emissions_df.iterrows():
        probs = np.clip(row.values, 1e-10, 1)  # avoid log(0)
        ic = np.sum(probs * np.log2(probs / background))
        ic_per_position.append(ic)
    
    return np.array(ic_per_position)


def plot_information_content(all_hmms, figsize=(16, 10)):
    """Plot IC profiles for all HMMs in a grid."""
    n_hmms = len(all_hmms)
    cols = 4
    rows = (n_hmms + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    ic_summary = {}
    
    for idx, (hmm_name, (emissions_df, meta)) in enumerate(all_hmms.items()):
        ax = axes[idx]
        ic = calculate_information_content(emissions_df)
        
        # store summary stats
        ic_summary[hmm_name] = {
            'mean_ic': np.mean(ic),
            'max_ic': np.max(ic),
            'positions_ic_gt_2': np.sum(ic > 2.0),
            'pct_conserved': 100 * np.sum(ic > 2.0) / len(ic),
            'length': len(ic)
        }
        
        ax.fill_between(range(len(ic)), ic, alpha=0.7, color='steelblue')
        ax.axhline(y=2.0, color='red', linestyle='--', alpha=0.5)
        ax.set_xlabel('Position')
        ax.set_ylabel('IC (bits)')
        ax.set_title(f'{hmm_name}\nmean={np.mean(ic):.2f} bits')
        ax.set_ylim([0, 4.5])
    
    # hide unused subplots
    for idx in range(len(all_hmms), len(axes)):
        axes[idx].set_visible(False)
    
    plt.suptitle('Information Content per Position (red line = IC > 2.0 threshold)', y=1.02)
    plt.tight_layout()
    return fig, pd.DataFrame(ic_summary).T

fig, ic_summary_df = plot_information_content(all_hmms)
plt.show()

print("\nInformation Content Summary:")
print("(Higher mean IC = more conserved model overall)")
display(ic_summary_df.round(3))
# Out:
# Information Content Summary:
# (Higher mean IC = more conserved model overall)
#               mean_ic  max_ic  positions_ic_gt_2  pct_conserved  length
# 8ca.alpha.45    0.745   1.547                0.0          0.000   177.0
# 8ca.beta.45     0.697   2.029                3.0          1.149   261.0
# 8ca.delta.45    0.677   2.400               24.0          5.217   460.0
# 8ca.eta.45      0.697   2.104                7.0          0.844   829.0
# 8ca.gamma.45    0.733   1.626                0.0          0.000   181.0
# 8ca.iota.45     0.738   1.688                0.0          0.000   216.0
# 8ca.theta.45    0.740   2.751               31.0          5.345   580.0
# 8ca.zeta.45     0.729   1.851                0.0          0.000   216.0

# %%
def plot_model_comparison(all_hmms, figsize=(14, 4)):
    """Side-by-side comparison of HMM structural properties."""
    data = []
    for hmm_name, (emissions_df, meta) in all_hmms.items():
        ic = calculate_information_content(emissions_df)
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        data.append({
            'family': family,
            'length': len(emissions_df),
            'mean_ic': np.mean(ic),
            'pct_conserved': 100 * np.sum(ic > 2.0) / len(ic)
        })
    
    model_df = pd.DataFrame(data).sort_values('length', ascending=True)
    
    fig, axes = plt.subplots(1, 3, figsize=figsize)
    
    # model lengths
    axes[0].barh(model_df['family'], model_df['length'], color='steelblue')
    axes[0].set_xlabel('Model Length (positions)')
    axes[0].set_title('HMM Length')
    
    # mean IC
    axes[1].barh(model_df['family'], model_df['mean_ic'], color='coral')
    axes[1].axvline(x=2.0, color='red', linestyle='--', alpha=0.5)
    axes[1].set_xlabel('Mean IC (bits)')
    axes[1].set_title('Average Conservation')
    
    # % conserved
    axes[2].barh(model_df['family'], model_df['pct_conserved'], color='forestgreen')
    axes[2].set_xlabel('% Positions with IC > 2.0')
    axes[2].set_title('Fraction Highly Conserved')
    
    plt.tight_layout()
    return fig, model_df

fig, model_comparison_df = plot_model_comparison(all_hmms)
plt.show()
display(model_comparison_df.round(2))
# Out:
#   family  length  mean_ic  pct_conserved
# 0  alpha     177     0.74           0.00
# 4  gamma     181     0.73           0.00
# 5   iota     216     0.74           0.00
# 7   zeta     216     0.73           0.00
# 1   beta     261     0.70           1.15
# 2  delta     460     0.68           5.22
# 6  theta     580     0.74           5.34
# 3    eta     829     0.70           0.84

# %%
def plot_bitscore_distributions(df, figsize=(12, 5)):
    """Plot bit score distributions overall and per family."""
    plot_df = df[df['pred_class'] != 'NO_HIT'].copy()
    
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # overall histogram
    axes[0].hist(plot_df['bit_score'], bins=50, edgecolor='black', alpha=0.7, color='steelblue')
    axes[0].set_xlabel('Bit Score')
    axes[0].set_ylabel('Count')
    axes[0].set_title('Overall Bit Score Distribution')
    
    # per-class boxplot (ordered by median)
    class_order = (plot_df.groupby('pred_class')['bit_score']
                   .median()
                   .sort_values(ascending=False)
                   .index.tolist())
    sns.boxplot(data=plot_df, x='pred_class', y='bit_score', order=class_order, ax=axes[1])
    axes[1].set_xlabel('Predicted Family')
    axes[1].set_ylabel('Bit Score')
    axes[1].set_title('Bit Score by Family')
    axes[1].tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    return fig

if df is not None:
    fig = plot_bitscore_distributions(df)
    plt.show()

# %%
def plot_normalized_scores(df, all_hmms, figsize=(10, 5)):
    """Plot bit scores normalized by HMM length."""
    plot_df = df[df['pred_class'] != 'NO_HIT'].copy()
    
    # get model lengths per family
    model_lengths = {}
    for hmm_name, (emissions_df, meta) in all_hmms.items():
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        model_lengths[family] = len(emissions_df)
    
    plot_df['model_length'] = plot_df['pred_class'].map(model_lengths)
    plot_df['norm_score'] = plot_df['bit_score'] / plot_df['model_length']
    
    fig, ax = plt.subplots(figsize=figsize)
    
    class_order = (plot_df.groupby('pred_class')['norm_score']
                   .median()
                   .sort_values(ascending=False)
                   .index.tolist())
    
    sns.boxplot(data=plot_df, x='pred_class', y='norm_score', order=class_order, ax=ax)
    ax.set_xlabel('Predicted Family')
    ax.set_ylabel('Bit Score / Model Length')
    ax.set_title('Length-Normalized Bit Scores\n(bits per position)')
    ax.tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    return fig

if df is not None:
    fig = plot_normalized_scores(df, all_hmms)
    plt.show()

# %%
def plot_score_density_overlay(df, figsize=(12, 7)):
    """Overlay density plots to visualize score separation between families."""
    plot_df = df[df['pred_class'] != 'NO_HIT'].copy()
    
    fig, ax = plt.subplots(figsize=figsize)
    
    families = sorted(plot_df['pred_class'].unique())
    for family in families:
        subset = plot_df[plot_df['pred_class'] == family]['bit_score']
        if len(subset) > 20:  # need enough points for KDE
            subset.plot.kde(ax=ax, label=f'{family} (n={len(subset):,})', linewidth=2)
    
    ax.set_xlabel('Bit Score', fontsize=16)
    ax.set_ylabel('Density', fontsize=16)
    ax.set_title('Bit Score Distributions by Family', fontsize=18)
    ax.tick_params(axis='both', labelsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=15)
    ax.set_xlim(left=0)
    
    plt.tight_layout()
    return fig

if df is not None:
    fig = plot_score_density_overlay(df)
    
    # Save at 300 dpi
    out_png = RESULTS / "bit_score_density_by_family.png"
    fig.savefig(out_png, dpi=300, bbox_inches='tight')
    
    plt.show()
    plt.close()

# %%
def analyze_no_hits(df):
    """Summarize sequences with no HMM hits."""
    total = len(df)
    no_hits = df[df['pred_class'] == 'NO_HIT']
    with_hits = df[df['pred_class'] != 'NO_HIT']
    
    print("=" * 50)
    print("NO_HIT SUMMARY")
    print("=" * 50)
    print(f"Total sequences:        {total:>10,}")
    print(f"Sequences with hits:    {len(with_hits):>10,} ({100*len(with_hits)/total:>5.1f}%)")
    print(f"Sequences with NO hits: {len(no_hits):>10,} ({100*len(no_hits)/total:>5.1f}%)")
    print("=" * 50)
    
    return no_hits

if df is not None:
    no_hits_df = analyze_no_hits(df)
# Out:
# ...
# NO_HIT SUMMARY
# ...
# Total sequences:           148,727
# Sequences with hits:       140,974 ( 94.8%)
# Sequences with NO hits:      7,753 (  5.2%)
# ...

# %%
def calculate_shannon_entropy(emissions_df):
    """Calculate Shannon entropy at each position. Max = log2(20) ≈ 4.32 bits."""
    entropies = []
    for idx, row in emissions_df.iterrows():
        probs = np.clip(row.values, 1e-10, 1)
        entropy = -np.sum(probs * np.log2(probs))
        entropies.append(entropy)
    return np.array(entropies)

def find_conserved_regions(ic_array, threshold=1.5, min_length=3):
    """
    Find stretches of consecutive positions with IC above threshold.
    These represent potential conserved motifs or functional regions.
    """
    regions = []
    in_region = False
    start = 0
    
    for i, ic in enumerate(ic_array):
        if ic >= threshold and not in_region:
            in_region = True
            start = i
        elif ic < threshold and in_region:
            in_region = False
            if i - start >= min_length:
                regions.append((start + 1, i, i - start))  # 1-indexed positions
    
    # handle region at end
    if in_region and len(ic_array) - start >= min_length:
        regions.append((start + 1, len(ic_array), len(ic_array) - start))
    
    return regions

def plot_entropy_profiles(all_hmms, figsize=(18, 14)):
    """Plot entropy profiles with conserved regions highlighted."""
    n_hmms = len(all_hmms)
    cols = 2
    rows = (n_hmms + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    profile_stats = []
    
    for idx, (hmm_name, (emissions_df, meta)) in enumerate(all_hmms.items()):
        ax = axes[idx]
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        
        # calculate entropy and IC
        entropy = calculate_shannon_entropy(emissions_df)
        ic = calculate_information_content(emissions_df)
        
        # find conserved regions (IC > 1.5)
        conserved = find_conserved_regions(ic, threshold=1.5, min_length=3)
        
        # plot entropy profile
        positions = np.arange(1, len(entropy) + 1)
        ax.fill_between(positions, entropy, alpha=0.6, color='steelblue', label='Entropy')
        ax.axhline(y=np.log2(20), color='gray', linestyle=':', linewidth=2, alpha=0.5, label='Max entropy')
        
        # highlight conserved regions
        for start, end, length in conserved:
            ax.axvspan(start, end, alpha=0.3, color='red', label='Conserved' if start == conserved[0][0] else '')
        
        ax.set_xlabel('Position', fontsize=15)
        ax.set_ylabel('Shannon Entropy (bits)', fontsize=15)
        ax.set_title(f'{family.upper()}\n(length={len(entropy)}, mean H={np.mean(entropy):.2f})', fontsize=16)
        ax.tick_params(axis='both', labelsize=14)
        ax.set_ylim([0, 4.5])
        ax.legend(loc='upper right', fontsize=14)
        
        # collect stats
        profile_stats.append({
            'Family': family,
            'Length': len(entropy),
            'Mean Entropy': np.mean(entropy),
            'Min Entropy': np.min(entropy),
            'Std Entropy': np.std(entropy),
            'Mean IC': np.mean(ic),
            'Max IC': np.max(ic),
            'Conserved Regions': len(conserved),
            'Conserved Positions': sum([r[2] for r in conserved])
        })
    
    # hide unused subplots
    for idx in range(len(all_hmms), len(axes)):
        axes[idx].set_visible(False)
    
    plt.tight_layout()
    return fig, pd.DataFrame(profile_stats)

fig, entropy_stats = plot_entropy_profiles(all_hmms)

# Save at 300 dpi
out_png = RESULTS / "entropy_profiles_all_families.png"
fig.savefig(out_png, dpi=300, bbox_inches='tight')

plt.show()
plt.close()

print("\nEntropy & Conservation Statistics:")
display(entropy_stats.round(3))
# Out:
# Entropy & Conservation Statistics:
#   Family  Length  Mean Entropy  Min Entropy  Std Entropy  Mean IC  Max IC  \
# 0  alpha     177         3.577        2.775        0.345    0.745   1.547
# 1   beta     261         3.624        2.293        0.474    0.697   2.029
# 2  delta     460         3.645        1.922        0.580    0.677   2.400
# 3    eta     829         3.625        2.218        0.482    0.697   2.104
# 4  gamma     181         3.589        2.696        0.388    0.733   1.626
# 5   iota     216         3.584        2.634        0.408    0.738   1.688
# 6  theta     580         3.582        1.571        0.604    0.740   2.751
# 7   zeta     216         3.593        2.471        0.460    0.729   1.851
#
#    Conserved Regions  Conserved Positions
# 0                  0                    0
# 1                  1                    3
# 2                  3                    9
# 3                  0                    0
# 4                  0                    0
# ...

# %%
# Beta entropy plot
def calculate_shannon_entropy(emissions_df):
    """Calculate Shannon entropy at each position."""
    entropies = []
    for idx, row in emissions_df.iterrows():
        probs = np.clip(row.values, 1e-10, 1)
        entropy = -np.sum(probs * np.log2(probs))
        entropies.append(entropy)
    return np.array(entropies)

def find_conserved_regions(ic_array, threshold=1.5, min_length=3):
    """Find stretches of consecutive positions with IC above threshold."""
    regions = []
    in_region = False
    start = 0
    
    for i, ic in enumerate(ic_array):
        if ic >= threshold and not in_region:
            in_region = True
            start = i
        elif ic < threshold and in_region:
            in_region = False
            if i - start >= min_length:
                regions.append((start + 1, i, i - start))
    
    if in_region and len(ic_array) - start >= min_length:
        regions.append((start + 1, len(ic_array), len(ic_array) - start))
    
    return regions

# Get beta data
beta_emissions, beta_meta = all_hmms['8ca.beta.45']

# Calculate entropy and IC
entropy = calculate_shannon_entropy(beta_emissions)
ic = calculate_information_content(beta_emissions)

# Find conserved regions
conserved = find_conserved_regions(ic, threshold=1.5, min_length=3)

# Plot
fig, ax = plt.subplots(figsize=(12, 6))
positions = np.arange(1, len(entropy) + 1)
ax.fill_between(positions, entropy, alpha=0.6, color='steelblue', label='Entropy')
ax.axhline(y=np.log2(20), color='gray', linestyle=':', linewidth=2, alpha=0.5, label='Max entropy')

# Highlight conserved regions
for i, (start, end, length) in enumerate(conserved):
    ax.axvspan(start, end, alpha=0.3, color='red', label='Conserved' if i == 0 else '')

ax.set_xlabel('Position', fontsize=16)
ax.set_ylabel('Shannon Entropy (bits)', fontsize=16)
ax.set_title(f'BETA\n(length={len(entropy)}, mean H={np.mean(entropy):.2f})', fontsize=18)
ax.tick_params(axis='both', labelsize=14)
ax.set_ylim([0, 4.5])
ax.legend(loc='upper right', fontsize=12)

plt.tight_layout()

# Save at 300 dpi
out_png = RESULTS / "beta_entropy_profile.png"
fig.savefig(out_png, dpi=300, bbox_inches='tight')

plt.show()
plt.close()

print(f"Conserved regions: {conserved}")
# Out:
# Conserved regions: [(212, 214, 3)]

# %%
def extract_conserved_motifs(all_hmms, top_n=10, ic_threshold=1.0):
    """
    Extract the most conserved positions from each HMM.
    Returns the top N positions by IC and their dominant amino acids.
    """
    motif_data = []
    
    for hmm_name, (emissions_df, meta) in all_hmms.items():
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        ic = calculate_information_content(emissions_df)
        
        # get top conserved positions
        top_indices = np.argsort(ic)[::-1][:top_n]
        
        for rank, pos_idx in enumerate(top_indices):
            pos = pos_idx + 1  # 1-indexed
            position_ic = ic[pos_idx]
            
            if position_ic < ic_threshold:
                continue
            
            # get amino acid probabilities at this position
            aa_probs = emissions_df.iloc[pos_idx].sort_values(ascending=False)
            top_aa = aa_probs.index[0]
            top_prob = aa_probs.iloc[0]
            second_aa = aa_probs.index[1]
            second_prob = aa_probs.iloc[1]
            
            motif_data.append({
                'Family': family,
                'Position': pos,
                'IC': position_ic,
                'Top AA': top_aa,
                'Top Prob': top_prob,
                'Second AA': second_aa,
                'Second Prob': second_prob,
                'Consensus': f"{top_aa}({top_prob:.0%})"
            })
    
    return pd.DataFrame(motif_data)

def plot_top_conserved_positions(all_hmms, top_n=5, figsize=(8, 5)):
    """Visualize the most conserved positions per family."""
    motif_df = extract_conserved_motifs(all_hmms, top_n=top_n, ic_threshold=0.5)
    
    if len(motif_df) == 0:
        print("No positions above IC threshold found.")
        return None, None
    
    fig, ax = plt.subplots(figsize=figsize)
    
    # dominant amino acid frequencies
    aa_counts = motif_df['Top AA'].value_counts()
    ax.bar(aa_counts.index, aa_counts.values, color='coral')
    ax.set_xlabel('Amino Acid')
    ax.set_ylabel('Count (across all families)')
    ax.set_title('Most Common AAs at Conserved Positions')
    
    plt.tight_layout()
    return fig, motif_df

fig, motif_df = plot_top_conserved_positions(all_hmms, top_n=10)
plt.show()

print("\nTop Conserved Positions by Family:")
display(motif_df.sort_values(['Family', 'IC'], ascending=[True, False]).round(3))
# Out:
# Top Conserved Positions by Family:
#    Family  Position     IC Top AA  Top Prob Second AA  Second Prob Consensus
# 0   alpha        96  1.547      G     0.553         A        0.061    G(55%)
# 1   alpha        83  1.547      G     0.553         A        0.061    G(55%)
# 2   alpha        50  1.547      G     0.553         A        0.061    G(55%)
# 3   alpha        63  1.547      G     0.553         A        0.061    G(55%)
# 4   alpha       113  1.547      G     0.553         A        0.061    G(55%)
# ..    ...       ...    ...    ...       ...       ...          ...       ...
# 75   zeta        60  1.851      G     0.620         A        0.053    G(62%)
# 76   zeta       107  1.851      G     0.620         A        0.053    G(62%)
# 77   zeta        61  1.851      G     0.620         A        0.053    G(62%)
# 78   zeta       135  1.851      G     0.620         A        0.053    G(62%)
# 79   zeta        56  1.688      P     0.590         A        0.048    P(59%)
#
# ...

# %%
def extract_conserved_motifs(all_hmms, top_n=10, ic_threshold=1.0):
    """
    Extract the most conserved positions from each HMM.
    Returns the top N positions by IC and their dominant amino acids.
    """
    motif_data = []
    
    for hmm_name, (emissions_df, meta) in all_hmms.items():
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        ic = calculate_information_content(emissions_df)
        
        # get top conserved positions
        top_indices = np.argsort(ic)[::-1][:top_n]
        
        for rank, pos_idx in enumerate(top_indices):
            pos = pos_idx + 1  # 1-indexed
            position_ic = ic[pos_idx]
            
            if position_ic < ic_threshold:
                continue
            
            # get amino acid probabilities at this position
            aa_probs = emissions_df.iloc[pos_idx].sort_values(ascending=False)
            top_aa = aa_probs.index[0]
            top_prob = aa_probs.iloc[0]
            second_aa = aa_probs.index[1]
            second_prob = aa_probs.iloc[1]
            
            motif_data.append({
                'Family': family,
                'Position': pos,
                'IC': position_ic,
                'Top AA': top_aa,
                'Top Prob': top_prob,
                'Second AA': second_aa,
                'Second Prob': second_prob,
                'Consensus': f"{top_aa}({top_prob:.0%})"
            })
    
    return pd.DataFrame(motif_data)

def plot_top_conserved_positions_per_family(all_hmms, top_n=10, figsize=(16, 10)):
    """Visualize the most conserved positions per family in separate subplots."""
    motif_df = extract_conserved_motifs(all_hmms, top_n=top_n, ic_threshold=0.5)
    
    if len(motif_df) == 0:
        print("No positions above IC threshold found.")
        return None, None
    
    families = sorted(motif_df['Family'].unique())
    n_families = len(families)
    cols = 4
    rows = (n_families + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    for idx, family in enumerate(families):
        ax = axes[idx]
        fam_data = motif_df[motif_df['Family'] == family]
        aa_counts = fam_data['Top AA'].value_counts()
        
        ax.bar(aa_counts.index, aa_counts.values, color='coral')
        ax.set_xlabel('Amino Acid')
        ax.set_ylabel('Count')
        ax.set_title(f'{family.upper()}')
    
    # hide unused subplots
    for idx in range(n_families, len(axes)):
        axes[idx].set_visible(False)
    
    plt.suptitle('Most Common AAs at Conserved Positions by Family', y=1.02, fontsize=14)
    plt.tight_layout()
    return fig, motif_df

fig, motif_df = plot_top_conserved_positions_per_family(all_hmms, top_n=10)
plt.show()

# %%
def compare_aa_preferences(all_hmms, figsize=(14, 10)):
    """
    Compare average amino acid preferences across all HMM positions.
    Shows which AAs are enriched/depleted in each family.
    """
    aa_profiles = {}
    
    for hmm_name, (emissions_df, meta) in all_hmms.items():
        family = hmm_name.split('.')[1] if '.' in hmm_name else hmm_name
        # average probability for each AA across all positions
        aa_profiles[family] = emissions_df.mean()
    
    profile_df = pd.DataFrame(aa_profiles)
    
    # calculate deviation from uniform (1/20 = 0.05)
    deviation_df = profile_df - 0.05
    
    fig, axes = plt.subplots(2, 1, figsize=figsize)
    
    # heatmap of average AA preferences
    ax1 = axes[0]
    sns.heatmap(profile_df, cmap='YlOrRd', annot=False, ax=ax1,
                cbar_kws={'label': 'Mean Probability'})
    ax1.set_title('Average Amino Acid Preferences by Family')
    ax1.set_xlabel('CA Family')
    ax1.set_ylabel('Amino Acid')
    
    # heatmap of deviations from uniform
    ax2 = axes[1]
    sns.heatmap(deviation_df, cmap='RdBu_r', center=0, annot=False, ax=ax2,
                cbar_kws={'label': 'Deviation from Uniform'})
    ax2.set_title('Deviation from Uniform AA Distribution\n(Red = enriched, Blue = depleted)')
    ax2.set_xlabel('CA Family')
    ax2.set_ylabel('Amino Acid')
    
    plt.tight_layout()
    return fig, profile_df

fig, aa_profile_df = compare_aa_preferences(all_hmms)
plt.show()

# show most enriched AAs per family
print("\nTop 3 Enriched Amino Acids per Family:")
for col in aa_profile_df.columns:
    top3 = aa_profile_df[col].sort_values(ascending=False).head(3)
    print(f"  {col}: {', '.join([f'{aa}({p:.1%})' for aa, p in top3.items()])}")
# Out:
# Top 3 Enriched Amino Acids per Family:
#   alpha: L(9.1%), V(8.6%), A(7.9%)
#   beta: L(8.3%), A(7.7%), V(7.3%)
#   delta: A(8.2%), S(7.5%), E(7.4%)
#   eta: K(8.4%), E(7.8%), L(7.7%)
#   gamma: V(9.6%), L(8.3%), I(8.0%)
#   iota: A(9.4%), L(8.2%), V(7.9%)
#   theta: A(9.1%), L(8.5%), V(7.4%)
#   zeta: A(8.3%), V(8.1%), L(7.9%)

# %%
HELDOUT_CSV = REBASE / "06_dirs_heldout_predictions.csv"
CM_CSV = REBASE / "06_dirs_confusion_matrix.csv"

if HELDOUT_CSV.exists():
    heldout = pd.read_csv(HELDOUT_CSV)
    print(f"Loaded {len(heldout):,} held-out sequences")
    print(f"Columns: {list(heldout.columns)}")
    print(f"\nTrue class distribution:")
    print(heldout['true_class'].value_counts())
    print(f"\nPredicted class distribution:")
    print(heldout['pred_class'].value_counts())
    display(heldout.head())
else:
    print(f"File not found: {HELDOUT_CSV}")
    print("Run your held-out evaluation pipeline first.")
    heldout = None
# Out:
# Loaded 119 held-out sequences
# Columns: ['seq_id', 'pred_model', 'bit_score', 'evalue', 'pred_class', 'true_class', 'correct']
#
# True class distribution:
# true_class
# 8ca.iota.45     20
# 8ca.beta.45     19
# 8ca.gamma.45    18
# 8ca.alpha.45    17
# 8ca.zeta.45     15
# 8ca.theta.45    12
# 8ca.delta.45     9
# 8ca.eta.45       9
# Name: count, dtype: int64
#
# Predicted class distribution:
# pred_class
# iota     20
# beta     19
# gamma    18
# alpha    17
# zeta     15
# theta    12
# delta     9
# eta       9
# Name: count, dtype: int64
#            seq_id    pred_model  bit_score        evalue pred_class  \
# 0      PAV05238.1  8ca.alpha.45      309.5  2.300000e-96      alpha
# 1  WP_321423126.1  8ca.alpha.45      309.2  2.700000e-96      alpha
# 2  WP_286478278.1  8ca.alpha.45      318.6  3.600000e-99      alpha
# 3  WP_088540216.1  8ca.alpha.45      313.0  1.900000e-97      alpha
# 4    MCC7562678.1  8ca.alpha.45      296.5  2.100000e-92      alpha
#
# ...

# %%
def normalize_class_name(name):
    """Extract family name from various formats."""
    if pd.isna(name):
        return name
    name = str(name)
    # Handle "8ca.alpha.45" format -> "alpha"
    if name.startswith('8ca.'):
        parts = name.split('.')
        if len(parts) >= 2:
            return parts[1]
    # Handle "NO_HIT" or already simple names
    return name.lower()


# Apply normalization to both columns
heldout['true_class_norm'] = heldout['true_class'].apply(normalize_class_name)
heldout['pred_class_norm'] = heldout['pred_class'].apply(normalize_class_name)

# Recompute 'correct' column
heldout['correct'] = heldout['true_class_norm'] == heldout['pred_class_norm']

print("After normalization:")
print(f"  true_class_norm unique: {sorted(heldout['true_class_norm'].unique())}")
print(f"  pred_class_norm unique: {sorted(heldout['pred_class_norm'].unique())}")
print(f"\nAccuracy: {heldout['correct'].mean():.4f}")
print(f"Correct predictions: {heldout['correct'].sum()} / {len(heldout)}")

display(heldout[['seq_id', 'true_class', 'true_class_norm', 'pred_class', 'pred_class_norm', 'correct']].head(10))
# Out:
# After normalization:
#   true_class_norm unique: ['alpha', 'beta', 'delta', 'eta', 'gamma', 'iota', 'theta', 'zeta']
#   pred_class_norm unique: ['alpha', 'beta', 'delta', 'eta', 'gamma', 'iota', 'theta', 'zeta']
#
# Accuracy: 1.0000
# Correct predictions: 119 / 119
#            seq_id    true_class true_class_norm pred_class pred_class_norm  \
# 0      PAV05238.1  8ca.alpha.45           alpha      alpha           alpha
# 1  WP_321423126.1  8ca.alpha.45           alpha      alpha           alpha
# 2  WP_286478278.1  8ca.alpha.45           alpha      alpha           alpha
# 3  WP_088540216.1  8ca.alpha.45           alpha      alpha           alpha
# 4    MCC7562678.1  8ca.alpha.45           alpha      alpha           alpha
# 5  WP_297899156.1  8ca.alpha.45           alpha      alpha           alpha
# 6      KZX10472.1  8ca.alpha.45           alpha      alpha           alpha
# 7  WP_303295131.1  8ca.alpha.45           alpha      alpha           alpha
# ...

# %%
def calculate_per_family_metrics(df, true_col='true_class_norm', pred_col='pred_class_norm'):
    """Calculate classification metrics for each family."""
    families = sorted([f for f in df[true_col].unique() if pd.notna(f) and f != 'no_hit'])
    
    results = []
    for family in families:
        tp = ((df[true_col] == family) & (df[pred_col] == family)).sum()
        fn = ((df[true_col] == family) & (df[pred_col] != family)).sum()
        fp = ((df[true_col] != family) & (df[pred_col] == family)).sum()
        tn = ((df[true_col] != family) & (df[pred_col] != family)).sum()
        
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else np.nan
        specificity = tn / (tn + fp) if (tn + fp) > 0 else np.nan
        precision = tp / (tp + fp) if (tp + fp) > 0 else np.nan
        f1 = 2 * (precision * sensitivity) / (precision + sensitivity) if (precision + sensitivity) > 0 else np.nan
        
        results.append({
            'Family': family,
            'N True': tp + fn,
            'N Predicted': tp + fp,
            'TP': tp, 'FN': fn, 'FP': fp, 'TN': tn,
            'Sensitivity': sensitivity,
            'Specificity': specificity,
            'Precision': precision,
            'F1': f1
        })
    
    return pd.DataFrame(results)


def plot_metrics_summary(metrics_df, figsize=(12, 5)):
    """Visualize sensitivity, specificity, precision, F1 per family."""
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    plot_df = metrics_df.sort_values('F1', ascending=True)
    
    # plot 1: sensitivity vs specificity
    ax1 = axes[0]
    x = np.arange(len(plot_df))
    width = 0.35
    ax1.barh(x - width/2, plot_df['Sensitivity'], width, label='Sensitivity', color='steelblue')
    ax1.barh(x + width/2, plot_df['Specificity'], width, label='Specificity', color='coral')
    ax1.set_yticks(x)
    ax1.set_yticklabels(plot_df['Family'])
    ax1.set_xlabel('Score')
    ax1.set_title('Sensitivity & Specificity by Family')
    ax1.legend()
    ax1.set_xlim([0, 1.05])
    ax1.axvline(x=0.9, color='gray', linestyle='--', alpha=0.5)
    
    # plot 2: precision, recall, F1
    ax2 = axes[1]
    width = 0.25
    ax2.barh(x - width, plot_df['Precision'], width, label='Precision', color='forestgreen')
    ax2.barh(x, plot_df['Sensitivity'], width, label='Recall', color='steelblue')
    ax2.barh(x + width, plot_df['F1'], width, label='F1', color='purple')
    ax2.set_yticks(x)
    ax2.set_yticklabels(plot_df['Family'])
    ax2.set_xlabel('Score')
    ax2.set_title('Precision, Recall, F1 by Family')
    ax2.legend()
    ax2.set_xlim([0, 1.05])
    
    plt.tight_layout()
    return fig


metrics_df = calculate_per_family_metrics(heldout)
print("Per-Family Classification Metrics (Held-Out Test Set):")
display(metrics_df.round(4))

# fig = plot_metrics_summary(metrics_df)
# plt.show()

print(f"\nOverall Accuracy: {heldout['correct'].mean():.4f}")
print(f"Macro-averaged F1: {metrics_df['F1'].mean():.4f}")
# Out:
# Per-Family Classification Metrics (Held-Out Test Set):
#   Family  N True  N Predicted  TP  FN  FP   TN  Sensitivity  Specificity  \
# 0  alpha      17           17  17   0   0  102          1.0          1.0
# 1   beta      19           19  19   0   0  100          1.0          1.0
# 2  delta       9            9   9   0   0  110          1.0          1.0
# 3    eta       9            9   9   0   0  110          1.0          1.0
# 4  gamma      18           18  18   0   0  101          1.0          1.0
# 5   iota      20           20  20   0   0   99          1.0          1.0
# 6  theta      12           12  12   0   0  107          1.0          1.0
# 7   zeta      15           15  15   0   0  104          1.0          1.0
#
#    Precision   F1
# 0        1.0  1.0
# 1        1.0  1.0
# 2        1.0  1.0
# 3        1.0  1.0
# 4        1.0  1.0
# 5        1.0  1.0
# 6        1.0  1.0
# 7        1.0  1.0
# Overall Accuracy: 1.0000
# Macro-averaged F1: 1.0000

# %%
def plot_confusion_matrix_heatmap(df, true_col='true_class_norm', pred_col='pred_class_norm', 
                                   normalize=False, figsize=(10, 8)):
    """Plot confusion matrix as heatmap."""
    
    labels = sorted(set(df[true_col].unique()) | set(df[pred_col].unique()))
    labels = [l for l in labels if pd.notna(l) and l != 'no_hit']
    
    cm = np.zeros((len(labels), len(labels)), dtype=int)
    for i, true_label in enumerate(labels):
        for j, pred_label in enumerate(labels):
            cm[i, j] = ((df[true_col] == true_label) & (df[pred_col] == pred_label)).sum()
    
    if normalize:
        row_sums = cm.sum(axis=1, keepdims=True)
        cm_plot = np.divide(cm, row_sums, where=row_sums != 0).astype(float)
        fmt = '.2f'
        title = 'Normalized Confusion Matrix (by True Class)'
    else:
        cm_plot = cm
        fmt = 'd'
        title = 'Confusion Matrix'
    
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm_plot, annot=True, fmt=fmt, cmap='Blues',
                xticklabels=labels, yticklabels=labels, ax=ax)
    ax.set_xlabel('Predicted Class')
    ax.set_ylabel('True Class')
    ax.set_title(title)
    
    plt.tight_layout()
    return fig, cm, labels


# Raw counts
fig, cm, labels = plot_confusion_matrix_heatmap(heldout, normalize=False)
plt.show()

# Normalized (shows recall per class)
fig, cm_norm, _ = plot_confusion_matrix_heatmap(heldout, normalize=True)
plt.show()

# Print diagonal accuracy
print("\nPer-class accuracy (diagonal):")
for i, label in enumerate(labels):
    row_total = cm[i, :].sum()
    if row_total > 0:
        print(f"  {label}: {cm[i,i]}/{row_total} = {cm[i,i]/row_total:.1%}")
# Out:
# Per-class accuracy (diagonal):
#   alpha: 17/17 = 100.0%
#   beta: 19/19 = 100.0%
#   delta: 9/9 = 100.0%
#   eta: 9/9 = 100.0%
#   gamma: 18/18 = 100.0%
#   iota: 20/20 = 100.0%
#   theta: 12/12 = 100.0%
#   zeta: 15/15 = 100.0%

# %%
def analyze_prediction_confidence(df, true_col='true_class_norm', pred_col='pred_class_norm',
                                   score_col='bit_score', figsize=(12, 5)):
    """Analyze the confidence/scores of correct vs incorrect predictions."""
    
    eval_df = df.copy()
    eval_df['correct'] = eval_df[true_col] == eval_df[pred_col]
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    
    # Plot 1: Score distribution for correct predictions
    ax1 = axes[0]
    correct_scores = eval_df[eval_df['correct']][score_col].dropna()
    incorrect_scores = eval_df[~eval_df['correct']][score_col].dropna()
    
    if len(correct_scores) > 0:
        ax1.hist(correct_scores, bins=20, alpha=0.7, label=f'Correct (n={len(correct_scores)})', color='green')
    if len(incorrect_scores) > 0:
        ax1.hist(incorrect_scores, bins=20, alpha=0.7, label=f'Incorrect (n={len(incorrect_scores)})', color='red')
    ax1.set_xlabel('Bit Score')
    ax1.set_ylabel('Count')
    ax1.set_title('Score Distribution by Correctness')
    ax1.legend()
    
    # Plot 2: Score by family
    ax2 = axes[1]
    families = sorted(eval_df[true_col].unique())
    family_scores = [eval_df[eval_df[true_col] == f][score_col].dropna().values for f in families]
    ax2.boxplot(family_scores, labels=families)
    ax2.set_xlabel('True Family')
    ax2.set_ylabel('Bit Score')
    ax2.set_title('Prediction Scores by Family')
    ax2.tick_params(axis='x', rotation=45)
    
    # # Plot 3: Score vs E-value (log scale)
    # ax3 = axes[2]
    # ax3.scatter(eval_df[score_col], eval_df['evalue'], alpha=0.6, 
    #             c=eval_df['correct'].map({True: 'green', False: 'red'}))
    # ax3.set_xlabel('Bit Score')
    # ax3.set_ylabel('E-value')
    # ax3.set_yscale('log')
    # ax3.set_title('Bit Score vs E-value')
    
    plt.tight_layout()
    
    # Summary statistics
    print("Score Statistics:")
    print(f"  Overall mean bit score: {eval_df[score_col].mean():.1f}")
    print(f"  Overall std bit score:  {eval_df[score_col].std():.1f}")
    print(f"  Min bit score:          {eval_df[score_col].min():.1f}")
    print(f"  Max bit score:          {eval_df[score_col].max():.1f}")
    
    if len(incorrect_scores) > 0:
        print(f"\n  Incorrect predictions mean: {incorrect_scores.mean():.1f}")
    
    return fig


fig = analyze_prediction_confidence(heldout)
plt.show()
# Out:
# Score Statistics:
#   Overall mean bit score: 422.8
#   Overall std bit score:  206.5
#   Min bit score:          261.8
#   Max bit score:          1241.9

# %%
def per_family_score_summary(df, true_col='true_class_norm', score_col='bit_score'):
    """Detailed score statistics per family."""
    
    families = sorted([f for f in df[true_col].unique() if pd.notna(f)])
    
    results = []
    for family in families:
        fam_df = df[df[true_col] == family]
        scores = fam_df[score_col].dropna()
        
        results.append({
            'Family': family,
            'N': len(scores),
            'Mean Score': scores.mean(),
            'Std Score': scores.std(),
            'Min Score': scores.min(),
            'Max Score': scores.max(),
            'Median Score': scores.median()
        })
    
    return pd.DataFrame(results)

score_summary = per_family_score_summary(heldout)
print("Per-Family Score Statistics (Held-Out Set):")
display(score_summary.round(2))

# Visualize
fig, ax = plt.subplots(figsize=(12, 6))
families = score_summary['Family'].values
x = np.arange(len(families))
ax.bar(x, score_summary['Mean Score'], yerr=score_summary['Std Score'], 
       capsize=5, color='steelblue', alpha=0.7)
ax.set_xticks(x)
ax.set_xticklabels(families, rotation=45, ha='right', fontsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.set_xlabel('Family', fontsize=16)
ax.set_ylabel('Bit Score', fontsize=16)
ax.set_title('Mean Bit Score ± Std by Family', fontsize=18)
plt.tight_layout()

# Save at 300 dpi
out_png = RESULTS / "mean_bit_score_by_family.png"
fig.savefig(out_png, dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# Per-Family Score Statistics (Held-Out Set):
#   Family   N  Mean Score  Std Score  Min Score  Max Score  Median Score
# 0  alpha  17      301.72      14.06      276.4      323.2        299.80
# 1   beta  19      378.13      14.67      329.0      392.0        382.00
# 2  delta   9      548.51      24.87      512.8      582.1        556.20
# 3    eta   9     1002.33     196.90      597.8     1241.9        972.70
# 4  gamma  18      296.86      17.12      261.8      322.1        297.95
# 5   iota  20      365.22      13.66      335.2      382.9        369.40
# 6  theta  12      562.42     204.12      383.7      933.9        472.40
# 7   zeta  15      310.02      29.21      275.9      364.0        302.60
